# %% [markdown]
# ### 1. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2 retornando o resultado e o apresente.

# %%
def multiplicar():
    numero = int(input("digite um numero: "))
    r = numero * 2
    return r

def main():
    resultado = multiplicar()
    print("o resultado da multiplicação é",resultado)
main()
# Out:
# digite um numero: 4
# o resultado da multiplicação é 8

# %% [markdown]
# ### 2. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método para subtrair dois números, retornar o resultado e o apresentando.

# %%
def subtrair():
    n1 = float(input('Informe o primeiro valor: '))
    n2 = float(input('Informe o segundo valor: '))
    r = n1 - n2
    return r,n1,n2 # COM retorno
    # ou
    # return n1 - n2

def main():
    result, num1, num2 = subtrair()
    print(result,num1,num2)
    print(f'A diferença entre o primeiro número {num1:.2f} e o segundo {num2:.2f} é {result:.2f}' )
    # ou 
    result = subtrair()
    print('A diferença entre dois números é',result)

main()
# Out:
# Informe o primeiro valor: 3
# Informe o segundo valor: 2
# 1.0 3.0 2.0
# A diferença entre o primeiro número 3.00 e o segundo 2.00 é 1.00
# Informe o primeiro valor: 4
# Informe o segundo valor: 5
# A diferença entre dois números é (-1.0, 4.0, 5.0)

# %% [markdown]
# ### 3. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia a base e a altura de um triângulo e retorne/apresente sua área A = (base x altura)/2.

# %%
def triangulo():
    altura = int(input("informe a altura do triângulo :"))
    base = int(input("informe a base do triângulo :"))
    area = (altura * base)/2
    return area
def main():
    print(f"o resultado da area do triangulo é :{triangulo():.2f}" )
main()
# Out:
# informe a altura do triângulo :15
# informe a base do triângulo :3
# o resultado da area do triangulo é :22.50

# %% [markdown]
# ### 4. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia o lado de um quadrado e retorne sua área, area = lado².

# %%
def quadrado():
    num = int(input("informe o numero : "))
    valor = num**2
    return valor
def main():
    resultado = quadrado()
    print(f"o resultado do quadrado é {resultado:.0f}")
main()
# Out:
# informe o numero : 4
# o resultado do quadrado é 16

# %% [markdown]
# ###5. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne mostrando a str/string ‘É par’ ou se ‘É ímpar’.

# %%
def ParImpar():
    num = int(input("informe o numero : "))
    resultado = num % 2
    if resultado == 0:
        return "par"
    else:
        return "impar"
def main():
    print("o numero digitado é",ParImpar())
main()
# Out:
# informe o numero : 4
# o numero digitado é par

# %% [markdown]
# ###6. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne/mostre o valor bool **True** para par e **False** para ímpar.

# %%
def VerdFals():
    num = int(input("informe o numero: "))
    resultado = not(bool(num % 2))
    return resultado
def main():
    print("o numero tem a premissa ",VerdFals())
main()
# Out:
# informe o numero: 2
# o numero tem a premissa  True

# %% [markdown]
# ### 7. (Função com retorno sem parâmetro) Faça uma função/método que leia e armazene 5 elementos inteiros no vetor A, deverá ser gerado um vetor B, de mesmo tamanho, que armazenará o fatorial de cada elemento de A. Não use função pronta de cálculo de fatorial. Retorne/apresente o vetor B.

# %%
def fatorial():
    A = []
    B = []
    for i in range(5):
        A.append(int(input("informe o numero para fatoriar: ")))
        soma=1
        for n in range(1,(A[i]+1)):
            soma = soma * n  
        B.append(soma)
    return B
def main():
    resultado = fatorial()
    for i in range(5):
        print(resultado[i],end="\t")
main()
# Out:
# informe o numero para fatoriar: 1
# informe o numero para fatoriar: 2
# informe o numero para fatoriar: 3
# informe o numero para fatoriar: 4
# informe o numero para fatoriar: 5
# 1	2	6	24	120

# %% [markdown]
# ### 8. (Função com retorno sem parâmetro) Faça uma função/método retorne um vetor com os três primeiros números perfeitos. Sabe-se que um número é perfeito quando é igual a soma de seus divisores (exceto ele mesmo).
# Exemplo: os divisores de 6 são 1, 2 e 3, e 1 + 2 + 3 = 6, logo 6 é perfeito. Não use função pronta.
#
# 1º número perfeito: 6
#
# 2º número perfeito: 28
#
# 3º número perfeito: 496

# %%
def perfeito():
    A = []
    for n in range(1,497):
        soma = 0
        for d in range(1,n):
            if n % d == 0:
                soma = soma + d
        if n == soma:
                A.append(n)
    return A
def main():
    perfeitos = perfeito()
    print("os trÊs primeiros numeros perfeitos são: ")
    for i in range(3):
        print(perfeitos[i],end="\t")
main()
# Out:
# os trÊs primeiros numeros perfeitos são:
# 6	28	496

# %% [markdown]
# ### 9. (Função com retorno sem parâmetro) Foi realizada uma pesquisa sobre algumas características físicas de cinco habitantes de uma região. Foram coletados os seguintes dados de cada habitante: idade, sexo (M - masculino ou F - feminino), cor dos olhos (A - azuis ou C - castanhos), cor dos cabelos (L - louros, P - pretos ou C - castanhos).
#
# 1.   Faça uma função/método que leia esses dados, armazenando-os em vetores (listas);
# 2.   Faça uma função/método que determine e devolva a função principal a média de idades das pessoas com olhos castanhos e cabelos pretos;
# 3. Faça uma função/método que determine e devolva a função principal a maior idade entre os habitantes;
# 4.  Faça uma função/método que determine e devolva a função principal a quantidade de indivíduos do sexo feminino com idade entre 18 e 35 anos(inclusive) e que tenham olhos azuis e cabelos louros.

# %%
idade = []
sexo = []
olhos = []
cabelo = []

def cadastrar():
    for i in range(5):
        idade.append(int(input(f"informe a idade do {i+1}º habitante: ")))
        sexo.append(input(f"informe o sexo 'M' para masculino e 'f' para feminino do {i+1}º habitante: "))
        olhos.append(input(f"informe a cor dos olhos 'a' para azul e 'c' para castanho do {i+1}º habitante: "))
        cabelo.append(input(f"informe a cor dos cabelos 'l' para loiro 'p' preto 'c' castanhos do {i+1}º habitante: "))
def MediaIdade():
    soma = 0
    c = 0
    for i in range(len(idade)):
        if olhos[i] == "c" and cabelo[i] == "p":
            soma+=idade[i] 
            c+=1
        if c > 0:
            media = soma / c
        else:
            media = 0 
    return media
def maior():
    maior=0
    for i in range(len(idade)):
        if i == 0:
            maior = idade[i]
        if idade[i] > maior:
            maior = idade[i]
    return maior       
def unicos():
    soma = 0
    for i in range(len(idade)):
        if sexo[i] == "f" and (idade[i] > 18 and idade[i] < 35) and olhos[i] == "a" and cabelo[i] == "l":
            soma+=1
    return soma

def main():
    cadastrar()
    MediaIdade()
    maior()
    unicos()
    print(f"A media das idades é {MediaIdade()} o habitante mais antigo é {maior()} e as mulheres loiras de olhos azuis são {unicos()}")

main()
# Out:
# informe a idade do 1º habitante: 30
# informe o sexo 'M' para masculino e 'f' para feminino do 1º habitante: f
# informe a cor dos olhos 'a' para azul e 'c' para castanho do 1º habitante: a
# informe a cor dos cabelos 'l' para loiro 'p' preto 'c' castanhos do 1º habitante: l
# informe a idade do 2º habitante: 20
# informe o sexo 'M' para masculino e 'f' para feminino do 2º habitante: f
# informe a cor dos olhos 'a' para azul e 'c' para castanho do 2º habitante: a
# informe a cor dos cabelos 'l' para loiro 'p' preto 'c' castanhos do 2º habitante: l
# A media das idades é 0 o habitante mais antigo é 30 e as mulheres loiras de olhos azuis são 2
