# %% [markdown]
# #**P1 - Algoritmo - Término 21:30**.
# ## É uma prova de consulta ao seu material.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **NO DIA SEGUINTE**
# ###Dúvidas, dependendo do assunto, escreva no **chat PRIVADO** do Teams.

# %% [markdown]
# ###[1,50 pontos] **1.** Utilize a linguagem de programação PYTHON. Crie um programa que leia o ano de nascimento de uma pessoa e o ano atual, calcule e mostre a idade da pessoa em:
# a) anos
#
# b) meses

# %%
ano_nascimento = int(input('ano em que nasceu :' ))
ano_atual = int(input('ano atual :'))
idade_atual = ano_atual - ano_nascimento
mes = idade_atual * 12
print(">>>> " * 6)
print(f'vc tem {idade_atual} anos ou',end=" ")
print(mes,'meses de vida .')
# Out:
# ano em que nasceu :1991
# ano atual :2021
# >>>> >>>> >>>> >>>> >>>> >>>>
# vc tem 30 anos ou 360 meses de vida .

# %% [markdown]
# ###[2,00 pontos] **2.** Utilize a linguagem de programação PYTHON. Crie um programa que leia o salário de um funcionário. Calcule e apresente os seguintes itens:
# a) Valor descontado do INSS (Instituto Nacional do Seguro Social)
#
# b) Valor do salário líquido
#
# SALÁRIO R$ |  Alíquota INSS % |
#  ---|---
# até 1100.00  |	7.50  |
# de 1100.01 até 2203.48	| 9.00 |
# de 2203.49 até 3305.22	| 12.00 |
# de 3305.23 até 6433.57  | 14.00|
# Acima 6433.57 | R\$ 751.97|
#
# Observação: o valor R$ 751.97 é fixo para qualquer valor de salário acima de R\$ 6433.57, conhecido como teto do INSS.

# %%
salario = float(input("informe seu salário :"))
if salario <= 1100.00:
    desconto = salario * 7.50 / 100
    salario_atual = salario - desconto
elif salario >=  1100.01 and salario < 2203.49:
    desconto = salario * 9 / 100
    salario_atual = salario - desconto
elif salario >=  2203.49 and salario < 3305.23:	
    desconto = salario * 12 / 100
    salario_atual = salario - desconto
elif salario >=  3305.23 and salario < 6433.57:
    desconto = salario * 14 / 100
    salario_atual = salario - desconto
elif salario > 6433.57:
    desconto = 751.97
    salario_atual = salario - desconto
print('>>>>>' * 8)
print(f"o desconto do INSS é : {desconto}" )
print(f"o seu salário liguido é :{salario_atual}")
# Out:
# informe seu salário :5000
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# o desconto do INSS é : 700.0
# o seu salário liguido é :4300.0

# %% [markdown]
# ###[2,50 pontos] **3.** Utilize a linguagem de programação PYTHON. Crie um programa que leia o salário de 10 funcionários. Calcule e apresente a média de salários pagos acima de 2000 reais. Escolha a estrutura de repetição.

# %%
soma = 0
funcionario = 0
for contador in range(10):
    salario_func = float(input(f'informe {contador + 1}º salário :'))
    if salario_func >= 2000:
        soma = soma + salario_func
        funcionario = funcionario + 1
        media = soma / funcionario
print(">>>>> " * 8)
print(f'a média salarial é {media:.2f} :')
# Out:
# informe 1º salário :5000
# informe 2º salário :120
# informe 3º salário :500
# informe 4º salário :600
# informe 5º salário :700
# informe 6º salário :5000
# informe 7º salário :2500
# informe 8º salário :7500
# informe 9º salário :400.89
# informe 10º salário :350.50
# >>>>> >>>>> >>>>> >>>>> >>>>> >>>>> >>>>> >>>>>
# a média salarial é 5000.00 :
