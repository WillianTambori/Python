# %% [markdown]
# ### 1. (Função com retorno com parâmetro) Faça um programa contendo uma função/método que receba por parâmetro um número e o multiplique por 2, retorne e apresente o resultado da função.

# %%
# 4ª Função COM retorno COM parâmetro
def multiplicar(num):
    r = num * 2
    return r

def main():
    numero = int(input('Digite um número: '))
    print('O resultado é',multiplicar(numero))
    # ou
    x = multiplicar(numero)
    print('O resultado é..',x)
main()
# Out:
# Digite um número: 2
# O resultado é 4
# O resultado é.. 4

# %% [markdown]
# ### 2. (Função com retorno com parâmetro) Faça um programa contendo uma função/método que receba dois números via parâmetro, some os dois valores, retorne e apresente o resultado.

# %%
def soma(x,y):
    total = x + y 
    return total
def main():
    n = int(input("insira o numero para soma: "))
    n2 = int(input("insira outro numero para soma: "))
    print(f"A soma de {n} + {n2} é igual a {soma(n,n2)} ")
main()
# Out:
# insira o numero para soma: 1
# insira outro numero para soma: 2
# A soma de 1 + 2 é igual a 3

# %% [markdown]
# ### 3. (Função com retorno com parâmetro) Faça um programa contendo uma função/método que receba um valor de porcentagem de aumento via parâmetro, aplique este aumento a um salário de um funcionário, retorne e apresente o novo salário.

# %%
def aumento(x,y):
    novo = x * ((y/100)+1)
    return novo
def main():
    salario = float(input("informe o salário :"))
    porcent = int(input("informe a porcentagem: "))
    print(f"O novo salário é R${aumento(salario,porcent):.2f}")
main()
# Out:
# informe o salário :1000
# informe a porcentagem: 30
# O novo salário é R$1300.00

# %% [markdown]
# ### 4. (Função com retorno com parâmetro) Faça um programa contendo uma função/método que receba duas notas (P1, P2) calcule a média, chame outra função na main que avalie se este aluno esta aprovado ou reprovado retornando a str/string 'Aprovado' ou 'Reprovado'.

# %%
def media(x,y):
    M = (x + y) / 2
    return M
def resultado(a):
    if a > 6:
        c = "aprovado"
    else:
        c = "reprovado"
    return c
def main():
    nota1 = float(input("insira a nota da P1: "))
    nota2 = float(input("insira a nota da P2: "))
    nota = media(nota1,nota2)
    print(f"A média das notas é {nota} e o aluno foi {resultado(nota)}")
main()
# Out:
# insira a nota da P1: 10
# insira a nota da P2: 9
# A média das notas é 9.5 e o aluno foi aprovado

# %% [markdown]
# ### 5. (Função com retorno com parâmetro) Faça um programa contendo uma função/método que receba um valor de porcentagem de aumento e um salário via parâmetro, aplique este aumento ao salário do funcionário. Na parte principal do programa, na chamada da função, utilize um laço de repetição para ler 10 salários, chame a função para aplicar o aumento e gerar o novo salário, ainda dentro da estrutura de repetição acumule os novos salários e ao final apresente quanto será gasto no novo salário. Também apresente qual será a diferença entre o que se pagava para todos os funcionário e o que será pago após o aumento.

# %%
def aumento(a,b):
    aumento = a*(1 + b/100)
    return aumento
def main():
    salario = novo = 0
    porcent = int(input("insira a porcentagem do aumento: "))
    for i in range(2):
        A = float(input("insira o salário: "))
        B = aumento(A,porcent)
        salario+=A
        novo+=B
        diferença = novo - salario
    print(f"o gasto com o novo salário é {novo:.2f} e o antigo era {salario:.2f} tendo um aumento de {diferença:.2f} em folha salárial")
main()
# Out:
# insira a porcentagem do aumento: 10
# insira o salário: 1000
# insira o salário: 2000
# o gasto com o novo salário é 3300.00 e o antigo era 3000.00 tendo um aumento de 300.00 em folha salárial

# %% [markdown]
# ### 6. (Função com retorno com parâmetro) Faça um programa contendo algumas funções:
# a) Função para construir um menu de opções para uma calculadora:
#
#     Menu de cálculos
#     1.   Número ao quadrado
#     2.   Número ao cubo
#     3.   Raiz do número
#     4.   Raiz cúbica do número
#     Qual é a opção desejada?
#
# b) Desenvolva uma função para cada opção de cálculo.
#
# Observação: Na chamada da função deve-se utilizar uma estrutura de repetição que permita diversos cálculos, quando o usuário quiser sair da calculadora digitará qualquer valor diferente dos **números** do menu.
#
# A função de desenho/construção do menu, esta chamará todas as outras passando a elas o valor digitado.

# %%
def menu():
    print("menu de cálculos")
    O = ["ao quadrado","ao cubo","na raiz ","na raiz cúbica"]
    for i in range(len(O)):
        print(f"{i+1}.   Este numero {O[i]}")
    option = int(input(("digite a opção desejada ? ")))
    return option
def quadrada(x):
    result = x**2
    return result
def cubo(x):
    result = x ** 3
    return result
def RaizNumero(x):
    result = x ** 0.5
    return result  
def RaizCubica(x):
    result = x ** (1/3)
    return result
def resultado(n,m):
    if n == 1:
        r = quadrada(m)
    elif n == 2:
        r = cubo(m)
    elif n == 3:
        r = RaizNumero(m)
    elif n == 4:
        r = RaizCubica(m)
    else:
        r = 0
    return r
def main():
    resposta = 1
    while resposta != 0:
        num = int(input("insira o numero: "))
        n = menu()
        resposta = resultado(n,num)
        print(f"o resultado é {resultado(n,num)}" if resposta !=0 else "fim do programa" )
        print(">>>>>>>>>>><<<<<<<<<<<<")
        
main()
# Out:
# menu de cálculos
# 1.   Este numero ao quadrado
# 2.   Este numero ao cubo
# 3.   Este numero na raiz do numero
# 4.   Este numero na raiz cúbica
# o resultado é 4
# >>>>>>>>>>><<<<<<<<<<<<

# %% [markdown]
# ### 7. (Função com retorno com parâmetro) Faça um programa contendo algumas funções:
# a) Função para construir um menu de opções para uma calculadora:
#
#     *** Minha Calculadora ***
#     Digite um número.....:
#     Digite outro número..:
#         + Soma dois números
#         - Subtrai dois números
#         * Multiplica dois números
#         / Divide dois números
#     Qual opção deseja?
#
# b) Desenvolva uma função para cada opção de cálculo, **mas estas não terão retorno**.
#
# Observação: Na chamada da função deve-se utilizar uma estrutura de repetição que permita diversos cálculos, quando o usuário quiser sair da calculadora digitará qualquer valor diferente dos **caracteres** do menu.
#
# A função de desenho/construção do menu, chamará todas as outras passando a elas os valores digitados.

# %%
def calculadora():
    A = ["+ Soma","- subtrai","* multiplica","/ Divide "]
    print("*** minha Calculadora ***")
    for i in range(len(A)):
        print(f"{A[i]} dois números")
def soma(a,b):
    r = a + b
    print("o resultado é ",r)
def subtrair(a,b):
    r = a - b
    print("o resultado é ",r)
def multiplicar(a,b):
    r = a * b
    print("o resultado é ",r)
def dividir(a,b):
    r = a / b
    print("o resultado é ",r)
def main():
    o = 1
    while o == 1:
        n1 = int(input("digite um numero :"))
        n2 = int(input("digite outro numero :"))
        calculadora()
        menu = input("Qual opção vc deseja? ")
        if menu == "+":
            soma(n1,n2)
        elif menu == "-":
            subtrair(n1,n2)
        elif menu == "*":
            multiplicar(n1,n2)
        elif menu == "/":
            dividir(n1,n2)
        else:
            print("fim do programa")
            o = 2
main()
# Out:
# digite um numero :1
# digite outro numero :2
# *** minha Calculadora ***
# + Soma dois números
# - subtrai dois números
# * multiplica dois números
# / Divide  dois números
# Qual opção vc deseja? +
# o resultado é  3
# digite um numero :1
# digite outro numero :2
# *** minha Calculadora ***
# + Soma dois números
# - subtrai dois números
# * multiplica dois números
# / Divide  dois números
# Qual opção vc deseja? ç
# fim do programa

# %% [markdown]
# ### 8. (Função com retorno com parâmetro) Faça um programa contendo algumas funções:
# a) Função para construir um menu de opções para uma calculadora:
#
#     *** Minha Calculadora ***
#     Digite um número.....:
#     Digite outro número..:
#         + Soma dois números
#         - Subtrai dois números
#         * Multiplica dois números
#         / Divide dois números
#     Qual opção deseja?
#
# b) Desenvolva uma função para cada opção de cálculo.
#
# Observação: Na chamada da função deve-se utilizar uma estrutura de repetição que permita diversos cálculos, quando o usuário quiser sair da calculadora digitará qualquer valor diferente dos **caracteres** do menu.
#
# A função de desenho/construção do menu, chamará todas as outras passando a elas os valores digitados.

# %%
def calculadora():
    A = ["+ Soma","- subtrai","* multiplica","/ Divide "]
    print("*** minha Calculadora ***")
    for i in range(len(A)):
        print(f"{A[i]} dois números")
def soma(a,b):
    r = a + b
    return r
def subtrair(a,b):
    r = a - b
    return r
def multiplicar(a,b):
    r = a * b
    return r
def dividir(a,b):
    r = a / b
    return r
def main():
    o = 1
    while o == 1:
        n1 = int(input("digite um numero :"))
        n2 = int(input("digite outro numero :"))
        calculadora()
        menu = input("Qual opção vc deseja? ")
        if menu == "+":
            print("o resultado é :",soma(n1,n2))
            o = 1
        elif menu == "-":
            print("o resultado é ",subtrair(n1,n2))
            o = 1
        elif menu == "*":
            print("o resultaod é ",multiplicar(n1,n2))
            o = 1
        elif menu == "/":
            print("o resultado é ",dividir(n1,n2))
            o = 1
        else:
            print("fim do programa")
            o = 0

main()
# Out:
# digite um numero :1
# digite outro numero :2
# *** minha Calculadora ***
# + Soma dois números
# - subtrai dois números
# * multiplica dois números
# / Divide  dois números
# Qual opção vc deseja? +
# o resultado é : 3
# digite um numero :1
# digite outro numero :2
# *** minha Calculadora ***
# + Soma dois números
# - subtrai dois números
# * multiplica dois números
# / Divide  dois números
# Qual opção vc deseja? ç
# fim do programa
