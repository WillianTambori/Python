# %% [markdown]
# ### 1. Elabore uma estrutura para representar e armazenar 10 produtos (código, nome, preço). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura.

# %%
class Tipo_Produto:
    codigo = 0
    nome = ''
    preco = 0.0

arq_produto = open('produto.txt','w')
for i in range(2):
    tp = Tipo_Produto()
    tp.codigo = int(input('Informe o código do produto: '))
    tp.nome = input('Informe o nome do produto: ')
    tp.preco = float(input('Informe o preço do produto: '))
    arq_produto.write(f'{tp.codigo},{tp.nome},{tp.preco:.2f}\n')
arq_produto.close()

arq_produto = open('produto.txt','r')
for x in arq_produto.readlines():
    c,n,p = x.strip().split(',')
    print(c,'\t\t',n,'\t\t',p)
arq_produto.close()
# Out:
# Informe o código do produto: 1
# Informe o nome do produto: rodo
# Informe o preço do produto: 20
# Informe o código do produto: 2
# Informe o nome do produto: vassora
# Informe o preço do produto: 40
# 1 		 rodo 		 20.00
# 2 		 vassora 		 40.00

# %% [markdown]
# # Nova seção

# %% [markdown]
# ### 2. Elabore uma estrutura para representar e armazenar 10 produtos (código, nome, preço). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura.Construa um menu com as seguintes opções, cada uma delas deve ter uma função e a main para chamar todas elas.
#
# Menu de opções:
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair

# %%
def menu():
    print('Menu de opções')
    print('1. Cadastrar produtos')
    print('2. Visualizar todos os dados')
    print('3. Sair')
    opcao = int(input('Informe a opção desejada: '))
    return opcao
class product:
    code = 0
    name = "" 
    price = 0.0
def creat_file():
    file_product = open("Product.txt","w")
    for i in range(2):
        t = Tipo_Produto()
        t.code = int(input('Informe o código do produto: '))
        t.name = input('Informe o nome do produto: ')
        t.price = float(input('Informe o preço do produto: '))
        file_product.write(f'{t.code},{t.name},{t.price:.2f}\n')
    file_product.close()
def show_file():
    x = open("/content/Product.txt","r")
    print("código \t\tname  \tpreço")
    for i in x.readlines():
        c,n,p = i.strip().split(',')
        print("{0:^5}".format(c),end="")
        print("{0:>15}".format(n),end="")
        print("{0:>9}".format(p))
    x.close()

    file_product.close()
def main():
    op = menu()
    while op >= 1 and op <= 2:
        if op == 1:
            creat_file()
            print('Cadastro\n')
        elif op == 2:
            show_file()
            print('Visualizar\n')
        op = menu()
    print('\nTérmino de execução')

main()
# Out:
# Menu de opções
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 1
# Informe o código do produto: 1
# Informe o nome do produto: vassora
# Informe o preço do produto: 30
# Informe o código do produto: 2
# Informe o nome do produto: rodo
# Informe o preço do produto: 40
# Cadastro
#
# Menu de opções
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 2
# código 		name  	preço
#   1          vassora     30.00
#   2             rodo     40.00
# Visualizar
#
# Menu de opções
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 0
#
# Término de execução

# %% [markdown]
# ### 3. Elabore uma estrutura para representar e armazenar 10 alunos (matricula, nome, telefone). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura. Construa um menu com as seguintes opções, cada uma delas deve ter uma função e a main para chamar todas elas.
#
# Menu de opções:
# 1. Cadastrar alunos
# 2. Visualizar todos os dados
# 3. Sair

# %%
class matriculation:
    ra = 0
    name = ""
    phone = 0

def menu():
    print('Menu de opções')
    print('1. Cadastrar nome dos alunos')
    print('2. Visualizar todos os dados')
    print('3. Sair')
    op = int(input('Informe a opção desejada: '))
    return op    
def register_student():
    a = open("matriculation.txt","w")
    for i in range(2):
        g = matriculation()
        g.ra = int(input("informe o nº de matricula do aluno: "))
        g.name = input("informe o nome do aluno: ")
        g.phone = int(input("informe o telefone do aluno: "))
        a.write(f"{g.ra},{g.name},{g.phone}\n")
    a.close()
def show_matriculation():
    x = open("/content/matriculation.txt","r")
    print("matricula.......nome.......telefone")
    for i in x.readlines():
        r,n,p = i.strip().split(',')
        print("{0:<5}".format(r),end="")
        print("{0:>15}".format(n),end="")
        print("{0:>15}".format(p))
    x.close()
def main():
    op = menu()
    while op >= 1 and op <3:
        if op == 1:
            register_student()
        elif op == 2:
            show_matriculation()
        op = menu()
    print("programa terminado...")
main()
# Out:
# Menu de opções
# 1. Cadastrar nome dos alunos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 1
# informe o nº de matricula do aluno: 1
# informe o nome do aluno: leonardo
# informe o telefone do aluno: 9987676898
# informe o nº de matricula do aluno: 2
# informe o nome do aluno: vilma
# informe o telefone do aluno: 9965656787
# Menu de opções
# 1. Cadastrar nome dos alunos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 2
# matricula.......nome.......telefone
# 1           leonardo     9987676898
# 2              vilma     9965656787
# Menu de opções
# 1. Cadastrar nome dos alunos
# 2. Visualizar todos os dados
# 3. Sair
# Informe a opção desejada: 7
# programa terminado...

# %% [markdown]
# ### 4. Baixe o arquivo futebol.txt que esta na pasta Material do aula do Teams. Leia este arquivo e o apresente. Com os dados lidos, armazene na estrutura Futebol (posicao_jogo, altura, peso, imc), calcule o IMC (Índice de Massa Corporal), armazene na estrutura e também em outro arquivo, mas agora chamado futebol_imc.txt. Apresente este novo arquivo.
# Observação: esse exercício deve ser testado fora do Colab, no Idle ou qualquer outra IDE, porque usará um arquivo que estará na pasta material de aula do Teams.

# %%
class imc:
    position = ""
    stature = 0.0
    peso = 0.0
    IMC = 0.0

def show_soccer():
    print()
    print("\t\t futebol sem imc")
    print()
    x = open("futebol.txt","r")
    print("posição_______altura______peso")
    for i in x.readlines():
        r,n,p = i.strip().split(',')
        print("{0:<15}".format(r),end="")
        print("{0:>5}".format(n),end="")
        print("{0:>10}".format(p))
    x.close()
def show_imc():
    print()
    print("\t\t futebol com imc")
    print()
    x = open("futebol_imc.txt","r")
    print("posição________altura______peso______imc")
    for i in x.readlines():
        r,n,p,k= i.strip().split(',')
        print("{0:<15}".format(r),end="")
        print("{0:>5}".format(n),end="")
        print("{0:>10}".format(p),end="")
        print("{0:>10.5}".format(k))
    x.close()
def insert_imc():
    x = open("futebol.txt","r")
    o = open("futebol_imc.txt","w")
    for i in x.readlines():
        r,n,p = i.strip().split(',')
        t = imc()
        t.position = r
        t.stature = n
        t.peso = p
        t.imc = float(p)/float(n)**2
        o.write(f"{t.position},{t.stature},{t.peso},{t.imc}\n")
    x.close()
    o.close()
def main():
    show_soccer()
    insert_imc()
    show_imc()
    
main()
# Out:
# 		 futebol sem imc
#
# posição_______altura______peso
# Zagueiro        1.79      78.0
# Zagueiro        1.78      85.0
# Meio campo      1.75      71.1
# Meio campo      1.81      73.5
# Meio campo      1.75      73.5
# Goleiro         1.85      81.0
# Atacante        1.87      81.7
# Atacante        1.65      55.5
# Atacante        1.78      77.9
# Lateral         1.70      66.0
# Lateral         1.74      63.7
#
# 		 futebol com imc
#
# posição________altura______peso______imc
# Zagueiro        1.79      78.0     24.34
# Zagueiro        1.78      85.0     26.82
# Meio campo      1.75      71.1     23.21
# Meio campo      1.81      73.5     22.43
# Meio campo      1.75      73.5      24.0
# Goleiro         1.85      81.0     23.66
# Atacante        1.87      81.7     23.36
# Atacante        1.65      55.5     20.38
# Atacante        1.78      77.9     24.58
# Lateral         1.70      66.0     22.83
# Lateral         1.74      63.7     21.03
