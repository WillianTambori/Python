# %% [markdown]
# ##**P1 - 2º. semestre/2021 -   Início: 09:30   -    Término: 13:00**
# ## É uma prova de consulta ao seu material e vale 6 pontos.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **NO DIA SEGUINTE**
# ##Se precisar, apenas **escreva no chat privado**.
#
# ##**Caso use a estrutura de repetição "for", poderá usar o operador in, a função len(), função append()/vetor e a range() no for, apenas.**
# ##Caso entregue atrasado descontarei alguns pontos.
#
# ##Dúvidas, enviem mensagem no chat privado, apenas até 12:50 que é o horário de término da aula.
# ##Na próxima aula faremos a correção da prova.

# %% [markdown]
# ###**1.**	Para fazer o cadastro em uma rede social, o usuário deve preencher vários dados, inclusive um e-mail válido, ou seja, um e-mail deve conter UM caracter arroba **'@'** e UM ou MAIS caracteres ponto **'.'**
# ### Crie uma função que retorne como resposta, se um e-mail é 'válido' ou 'inválido'. Não use nenhum método/função pronto ou o operador **in** no if, da linguagem Python. **Avalie caracter por caracter**. Deve ser criada a função main para chamar a da verificação.

# %%
def verificar(a):
    p = r = 0
    for i in range(len(a)):
        if a[i] == "@":
            r += 1
        if a[i] == ".":
            p += 1
    if r == 1 and p >= 1:
        return "válido"
    else:
        return "inválido"
def main():
    x = input("informe o e-mail: ")
    print("o e-mail informado é ",verificar(x))
main()
# Out:
# informe o e-mail: willian@fatec.com.br
# o e-mail informado é  válido

# %% [markdown]
# ### **2.** Não use nenhum método/função pronto da linguagem Python.
#
# ###Desenvolva todas as funções a seguir:
#
# ###a) Faça uma função com retorno (um valor no INSS calculado) e com parâmetro (um salario e a alíquota de 9% do INSS) para calcular o imposto do INSS que é descontado de um funcionário.
#
# ###b) Faça uma função com retorno (um salário líquido) e com parâmetro (um salario, um valor do INSS) que calcule o salário líquido de cada funcionário.
#
# ###c) Na função main() num laço de repetição, preencha um vetor com o salário de 10 funcionários. Em outro laço chame as outras funções (a e b) e apresente o salário original, o valor que será descontado do INSS e o salário líquido gerado de todos os funcionários.

# %%
def inss(n,t):
    inss = n * t/100
    return inss
def liquido(s,n):
    calculo = s - n
    return calculo
def main():
    a = 9
    s = []
    for i in range (10):
        s.append(float(input(f"informe o salário do {i + 1}º funcionário: ")))
    for i in range(len(s)):
        desconto = inss(s[i],a)
        salarioFinal = liquido(s[i],desconto)
        print(f"<<<<<<<<<< funcionário {i + 1} >>>>>>>>>>>> ")
        print(f"O salário bruto é............R${s[i]:9.2f}")
        print(f"taxa de {a}% do INSS......... -R${desconto:8.2f}")
        print(f"O salário liguido ...........R${salarioFinal:9.2f}")
main()
# Out:
# informe o salário do 1º funcionário: 1000
# informe o salário do 2º funcionário: 2000.50
# informe o salário do 3º funcionário: 7000
# informe o salário do 4º funcionário: 8000
# informe o salário do 5º funcionário: 9000
# informe o salário do 6º funcionário: 1500
# informe o salário do 7º funcionário: 4600
# informe o salário do 8º funcionário: 3000
# informe o salário do 9º funcionário: 3500
# informe o salário do 10º funcionário: 8000
# <<<<<<<<<< funcionário 1 >>>>>>>>>>>>
# O salário bruto é............R$  1000.00
# taxa de 9% do INSS......... -R$   90.00
# O salário liguido ...........R$   910.00
# <<<<<<<<<< funcionário 2 >>>>>>>>>>>>
# O salário bruto é............R$  2000.50
# taxa de 9% do INSS......... -R$  180.04
# O salário liguido ...........R$  1820.45
# <<<<<<<<<< funcionário 3 >>>>>>>>>>>>
# O salário bruto é............R$  7000.00
# taxa de 9% do INSS......... -R$  630.00
# O salário liguido ...........R$  6370.00
# <<<<<<<<<< funcionário 4 >>>>>>>>>>>>
# ...
