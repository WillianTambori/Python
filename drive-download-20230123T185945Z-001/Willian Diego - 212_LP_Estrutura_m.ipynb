# %% [markdown]
# ### 1. Elabore uma estrutura para representar um produto (código, nome, preço). Aplique 10% de aumento no preço do produto e apresente.

# %%
class Tipo_Produto:
    codigo = 0
    nome = ''
    preco = 0.0

def mostrar_membros(p):
    print(f'\nCódigo: {p.codigo} \tNome: {p.nome} \tPreço R$ {p.preco:.2f}')

def main():
    #1º passo, inicializar uma variável que representará a estrutura/Tipo_Produto
    p1 = Tipo_Produto()
    p1.codigo = int (input('Informe o código do produto: '))
    p1.nome = input('Informe o nome do produto: ')
    p1.preco = float (input('Informe o preço do produto: '))
    mostrar_membros(p1)
    p1.preco = p1.preco + p1.preco * 10 / 100
    mostrar_membros(p1)

    p2 = Tipo_Produto()
    p2.codigo = int (input('Informe o código do produto: '))
    p2.nome = input('Informe o nome do produto: ')
    p2.preco = float (input('Informe o preço do produto: '))
    mostrar_membros(p2)
    p2.preco += p2.preco * 10 / 100
    mostrar_membros(p2)

main()
# Out:
# Informe o código do produto: 10
# Informe o nome do produto: escova
# Informe o preço do produto: 10
#
# Código: 10 	Nome: escova 	Preço R$ 10.00
#
# Código: 10 	Nome: escova 	Preço R$ 11.00
# Informe o código do produto: 12
# Informe o nome do produto: pasta
# Informe o preço do produto: 12
#
# Código: 12 	Nome: pasta 	Preço R$ 12.00
#
# Código: 12 	Nome: pasta 	Preço R$ 13.20

# %% [markdown]
# ### 2. Elabore uma estrutura para representar um produto (código, nome, preço). Cadastre 5 produtos, use vetor/lista. Aplique 10% de aumento no preço do produto e apresente todos os dados do preço.

# %%
class Tipo_Produto:
    codigo = 0
    nome = ''
    preco = 0.0

def mostrar_membros(p):
    print(f'Código: {p.codigo} \tNome: {p.nome} \tPreço R$ {p.preco:.2f}')

def main():
    #1º passo, inicializar uma variável que representará a estrutura/Tipo_Produto
    vet_produtos = []
    for i in range(2):
        p1 = Tipo_Produto()
        p1.codigo = int (input('Informe o código do produto: '))
        p1.nome = input('Informe o nome do produto: ')
        p1.preco = float (input('Informe o preço do produto: '))
        p1.preco = p1.preco + p1.preco * 10 / 100
        vet_produtos.append(p1)

    for i in range(len(vet_produtos)):
        mostrar_membros(vet_produtos[i])

main()
# Out:
# Informe o código do produto: 3
# Informe o nome do produto: roda
# Informe o preço do produto: 1100
# Informe o código do produto: 5
# Informe o nome do produto: pneu
# Informe o preço do produto: 300
# Código: 3 	Nome: roda 	Preço R$ 1210.00
# Código: 5 	Nome: pneu 	Preço R$ 330.00

# %% [markdown]
# ### 3. Elabore uma estrutura para representar um produto (código, nome, preço). **Crie uma função** para cadastrar 5 produtos. **Crie outra função** para aplicar 10% de aumento no preço do produto e apresente, por meio **de outra função**, todos os dados do produtos cadastrados, após o aumento.

# %%
class product:
    code = 0
    name = " "
    price = 0
def show_products(p):
    print()
    print(f"Código: {p.code} \tnome: {p.name} \tpreço R${p.increase:.2f} ;")
def increase(a):
    p = a * 1.10
    return p 
def main():
    vet_product = []
    for i in range(2):
        p = product()
        p.code = int(input("digite o código do produto: "))
        p.name = input("digite o nome do produto: ")
        p.price = int(input("digite o preço do produto: "))
        p.increase = increase(p.price)
        vet_product.append(p)
    for i in range(len(vet_product)):
        show_products(vet_product[i])
main()
# Out:
# digite o código do produto: 1
# digite o nome do produto: vassora
# digite o preço do produto: 5
# digite o código do produto: 2
# digite o nome do produto: rodo
# digite o preço do produto: 5
#
# Código: 1 	nome: vassora 	preço R$5.50 ;
#
# Código: 2 	nome: rodo 	preço R$5.50 ;

# %% [markdown]
# ### 4. Uma escola precisa montar o cadastro geral de seus alunos. Este cadastro deverá conter as seguintes informações por aluno: nome completo, data de nascimento, telefone, endereço e série atual. Levando em conta que esta escola possui no máximo 500 alunos, como você faria para estruturar estas informações num sistema de gerenciamento para a escola? Implemente utilizando estrutura. Também **use a criação de funções para cada operação**. Use o menu a seguir:
# Menu de opções:
# 1. Cadastrar alunos
# 2. Consulta por nome
# 3. Visualizar todos os dados
# 4. Sair

# %%
def options():
    A = ["1. cadastrar ","2. consultar por nome ","3. visualizar dados de todos "]
    print("*** opções disponivel ***")
    for i in range(len(A)):
        print(f"{A[i]}os alunos ")
    print("4. sair")
class students:
    name = ""
    birth_date = ""
    phone = 0
    address = " "
    series = 0
def consult(a):
    b = input("digite o nome do aluno a ser consultado: ")
    for i in range(len(a)):
        if a[i].name == b:
            show_students(a[i])
        else:
            print("nome não encontrado")
def show_students(p):
    print(f"nome: {p.name} \tdata de nascimento: {p.birth_date} \ttelefone: {p.phone} \tendereço: {p.address} \tsérie escolar: {p.series} ;")
def main():
    option = 0
    vet_students = []
    while option != 4:
        options()
        option = int(input("insira a opção"))
        if option == 1: 
            for i in range(5):
                s = students()
                s.name = input("insira o nome: ")
                s.birth_date = input("insira a data de nascimento :")
                s.phone = int(input("insira o telefone: "))
                s.address = input("insira o endereço: ")
                s.series = int(input("informe a serie do aluno: "))
                vet_students.append(s)
        elif option == 2:
            consult(vet_students)
        elif option == 3:
            for i in range(len(vet_students)):
                show_students(vet_students[i])
        else:
            print("opção invalida")
main()
print("obrigado por usar o sistema")
# Out:
# *** opções disponivel ***
# 1. cadastrar os alunos
# 2. consultar por nome os alunos
# 3. visualizar dados de todos os alunos
# 4. sair
# insira a opção1
# insira o nome: lais
# insira a data de nascimento :20/03/2021
# insira o telefone: 9999999
# insira o endereço: Rua dos pardais
# informe a serie do aluno: 4
# insira o nome: bruno
# insira a data de nascimento :08/02/1996
# insira o telefone: 9999444
# insira o endereço: rua americana
# informe a serie do aluno: 5
# *** opções disponivel ***
# 1. cadastrar os alunos
# 2. consultar por nome os alunos
# 3. visualizar dados de todos os alunos
# 4. sair
# insira a opção2
# digite o nome do aluno a ser consultado: bruno
# nome não encontrado
# nome: bruno 	data de nascimento: 08/02/1996 	telefone: 9999444 	endereço: rua americana 	série escolar: 5 ;
# *** opções disponivel ***
# 1. cadastrar os alunos
# 2. consultar por nome os alunos
# 3. visualizar dados de todos os alunos
# 4. sair
# insira a opção2
# ...

# %% [markdown]
# ### 5. Faça um programa que realize o cadastro de contas bancarias com as seguintes informações: numero da conta, nome do titular e saldo. O banco permitirá o cadastramento de 15 contas. **Crie uma função para cada opção do menu** a seguir. Utilize a estrutura na passagem de parâmetro:
# Menu de opções:
# 1. Cadastrar contas
# 2. Visualizar todas as contas
# 3. Consultar por nome
# 4. Alterar nome e saldo de um número de conta
# 5. Excluir a conta com menor saldo
# 6. Sair
#
# Observação:
#
# * No item de menu 4. Alterar nome e/ou saldo de um número de conta, entenda que apenas pode ser alterado o nome e o saldo depois que você pesquisar pelo número da conta.
# * No item 5 do menu, encontre o menor saldo dentre todos cadastrados, **depois exclua esta ÚNICA conta.**. O assunto de excluir algo de um vetor foi dado na disciplina de Algoritmo.

# %%
# Percorra todo os vetor e quando a condição de enontrar um menor saldo for executada, guarde o índice
# Fora do laço de repetição, exclua pelo índice, por exemplo com o comando pop(índice)
class bank_account:
    account = 0
    holder = ""
    balance = 0.0
def options():
    A = ["cadastrar contas ","visualizar todas as contas ","consultar por nome ","Alterar nome e saldo de um número de conta","Excluir a conta com menor saldo","Sair"]
    print("*** opções disponivel ***")
    for i in range(len(A)):
        print(f"{i+1}. {A[i]}")
    print("*************************")
def show_account(l):
    print(f"numero da conta bancária: {l.account} \tTitular da conta: {l.holder} \tSaldo em conta: R${ l.balance} ;")
def consult_name(x):
    name = input("infome o nome a ser consultado: ")
    c=0
    for i in range(len(x)):
        if x[i].holder == name:
            show_account(x[i])
            c+=1
    if c == 0:
        print("não encontrado")
def change(d):
    name = input("infome o nome do titular a ser Alterado: ")
    c=0
    for i in range(len(d)):
        if d[i].holder == name:
            c+=1
            print("alterando a conta nº..",d[i].account)
            d[i].holder = input("insira o novo titular")
            d[i].balance = float(input("insira o novo saldo da conta"))
            return d         
        if c == 0:
            print("não encontrado")
def lower_balance(x):
    menor = indice = 0
    for i in range(len(x)):
        if i == 0:
            menor = x[i].balance
        if x[i].balance < menor:
            menor = x[i].balance
            indice = i
    x.pop(indice)
    return x
    


def main():
    menu = 0
    vet_account = []
    while menu != 6:
        options()
        menu = int(input("escolha uma das opções a cima :"))
        if menu == 1:
            for i in range(2):
                a = bank_account()
                a.account = int(input("insira o numero da conta: "))
                a.holder = input("insira o nome do titular da conta: ")
                a.balance = float(input("insira o saldo inicial: "))
                vet_account.append(a)
        elif menu == 2:
            for i in range(len(vet_account)):
                show_account(vet_account[i])
        elif menu == 3:
            consult_name(vet_account)
        elif menu == 4:
            vet_account = change(vet_account)
        elif menu == 5:
            vet_account = lower_balance(vet_account)
        else:
            print("valor inválido")
    print(" obrigador por usar o sistema ")
main()
# Out:
# *** opções disponivel ***
# 1. cadastrar contas
# 2. visualizar todas as contas
# 3. consultar por nome
# 4. Alterar nome e saldo de um número de conta
# 5. Excluir a conta com menor saldo
# 6. Sair
# *************************
# escolha uma das opções a cima :1
# insira o numero da conta: 1
# insira o nome do titular da conta: fer
# insira o saldo inicial: 200
# insira o numero da conta: 2
# insira o nome do titular da conta: gu
# insira o saldo inicial: 300
# *** opções disponivel ***
# 1. cadastrar contas
# 2. visualizar todas as contas
# 3. consultar por nome
# 4. Alterar nome e saldo de um número de conta
# 5. Excluir a conta com menor saldo
# 6. Sair
# *************************
# escolha uma das opções a cima :5
# *** opções disponivel ***
# 1. cadastrar contas
# 2. visualizar todas as contas
# 3. consultar por nome
# 4. Alterar nome e saldo de um número de conta
# 5. Excluir a conta com menor saldo
# 6. Sair
# *************************
# escolha uma das opções a cima :2
# ...

# %% [markdown]
# ####6. Uma empresa prestadora de serviços armazena informações sobre os serviços prestados. Sabe-se que a empresa pode realizar no máximo três serviços diariamente. É de interesse de sua direção manter um histórico mensal (30 dias) sobre os serviços prestados.
# A empresa realiza quatro tipos de serviços:
#
# 1) pintura;
#
# 2) jardinagem;
#
# 3) faxina e
#
# 4) reforma em geral.
#
# Cada serviço realizado deve ser cadastrado com as seguintes informações: número do serviço, valor do serviço, código do serviço e código do cliente, **numa matriz 30x3 referente a estrutura Servico_prestado**.
#
# Cadastre/digite os quatro tipos de serviços (código e descrição) que a empresa poderá realizar. Para isso, utilize um vetor de quatro posições referente a **estrutura Tipo_servico**.
# O programa deverá mostrar o seguinte menu de opções:
# 1. Cadastrar os tipos de serviços
# 2. Mostrar todos os tipos de serviço
# 3. Cadastrar os serviços prestados
# 4. Mostrar todos os serviços prestados
# 5. Mostrar os serviços prestados em determinado dia
# 6. Mostrar os serviços prestados dentro de um intervalo de valor
# 7. Mostrar um relatório geral (separado por dia), que exiba, inclusive, a descrição do tipo do serviço
# 8. Sair
#
# **Para a opção 1**: deve-se cadastrar os tipos de serviços oferecidos pela empresa, com código e descrição.
#
# **Para a opção 3**: deve-se considerar que deverão ser cadastrados os serviços prestados ao logo do mês. Em cada dia podem ser cadastrados, no máximo, três serviços prestados.
#
# Utilize uma matriz capaz de armazenar em cada posição todas as informações referentes a um serviço prestado (número, valor, código do serviço, código do cliente). **Cada linha representa um dia do mês**. Dessa maneira, considere a matriz com dimensão 30 × 3.
#
# Solicite o dia em que o serviço foi prestado e as demais informações.
# Lembre-se de que a empresa só pode prestar os serviços que já tenham sido cadastrados no vetor de tipo de serviços.
#
# Caso o usuário digite um código de tipo de serviço inválido, o programa deverá mostrar uma mensagem de erro.
#
# Quando o usuário tentar cadastrar mais de três serviços prestados em um mesmo dia, também deverá mostrar uma mensagem de erro.
#
# **Para a opção 5**: o programa deverá receber o dia que se deseja consultar e mostrar os respectivos serviços prestados.
#
# **Para a opção 6**: o programa deverá receber o valor mínimo e o valor máximo e mostrar os serviços prestados que estiverem nesse intervalo.
#
# **Para a opção 7**: o programa deverá mostrar todos os serviços prestados, conforme o exemplo a seguir.
#
#                   DIA 01
#
#
# No do serviço| Valor do serviço R$| Código do serviço| Descrição| Código do cliente
# ---|---|---|---|---
# 100| 200,00| 1| Pintura| 1
# 150| 100,00| 3| Faxina| 5
# 201| 640,00| 4| Reforma em geral| 2
#
#                   DIA 02
#
# No do serviço| Valor do serviço R$| Código do serviço| Descrição| Código do cliente
# ---|---|---|---|---
# 301| 600,00| 4| Reforma em geral| 3
# 280| 352,00| 1| Pintura| 2
# 306| 200,00| 2| Jardinagem| 1

# %%
class kind:
    code = 0
    description = ''

class employ:
    number = 0
    value = 0.0
    service = 0
    client = 0

def options():
    A = ["Cadastrar os tipos de serviços","Mostrar todos os tipos de serviço ","Cadastrar os serviços prestados","Mostrar todos os serviços prestados","Mostrar os serviços prestados em determinado dia","Mostrar os serviços prestados dentro de um intervalo de valor","Mostrar um relatório geral (separado por dia), que exiba, inclusive, a descrição do tipo do serviço","Sair"]
    print("*** opções disponivel ***")
    for i in range(len(A)):
        print(f"{i+1}. {A[i]}")
    print("*************************")
    o = int(input("informe a opção desejada.."))
    return o

def register(p):
    for i in range(4):
        vet = kind() # inicializo/preparo a varável vts para representar a estrutura Tipo_Servico
        vet.code = int (input('Cadastre o número do tipo de serviço: '))
        vet.description = input('Cadastre a descrição do tipo de serviço: ')
        p.append(vet)
    return p

def show_kind(p):
    for i in range( len(p) ): # \t pula uma tabulação
        print('Código: ',p[i].code, '\tDescrição: ',p[i].description)

def check_kind(a,b):
    c=0
    for i in range(4):
        if b[i].code == a:
            c+=1
    if c == 0:
        return False
    else:
        return True

def register_employ(x,y):
    n = (int(input("informe a data do serviço: "))-1) 
    m = n+1
    for lin in range(n,m): # sp = Serviços Prestados
        date = []
        while len(date) < 3: 
            b = int(input('informe o código do tipo de serviço: '))
            # chamo a função primeiro para depois continuar digitando, pois o código é válido
            if check_kind(b,y): # se é verdadeiro/se encontrou o mesmo código, continua a digitação
                sp = employ() # inicializo/preparo a a variável para representar a estrutura
                sp.number = int( input('Cadastre o número da prestação de serviço: '))
                sp.value = float( input('Cadastre o valor da prestação de serviço: '))
                sp.service = b
                sp.client = int( input('Cadastre o código do cliente: '))
                date.append(sp)
            else:
                print("tipo de serviço não realizado ")
        x[n] = date
        print("quantidade de serviço por dia lotado: ")
    return x

def show_value(a,b,m):
     for lin in range(len(m)):
        for col in range(len(m[lin])):
            if m[lin][col].value >= a and m[lin][col].value <= b:
                print('\nDia',lin+1)
                print('Número   \t\tValor   \t\tCódigo do Tipo de Serviço   \tCódigo do Cliente')
                print(m[lin][col].number,'\t\t\t',m[lin][col].value,'\t\t\t',m[lin][col].service,'\t\t\t\t\t',m[lin][col].client)

def show_employ(m): # msp = matriz de serviços prestados
    for lin in range(len(m)):
        for col in range(len(m[lin])):
            if m[lin][col].number > 0:
                print('\nDia',lin+1)
                print('Número   \t\tValor   \t\tCódigo do Tipo de Serviço   \tCódigo do Cliente')
                print(m[lin][col].number,'\t\t\t',m[lin][col].value,'\t\t\t',m[lin][col].service,'\t\t\t\t\t',m[lin][col].client)

def description(a,b):
    c="não cadastrado"
    for i in range(len(b)):
        if b[i].code == a:
            c = b[i].description
    return c        

def show_month(m,n): # m = matriz de serviços prestados
    print('Número   \t\tValor   \t\tCódigo do Tipo de Serviço  \t\t\tDescrição do serviço  \tCódigo do Cliente')
    for lin in range(len(m)):
        print('\nDia',lin+1)
        for col in range(len(m[lin])):
            print(m[lin][col].number,'\t\t\t',m[lin][col].value,'\t\t\t',m[lin][col].service,'\t\t\t',description(m[lin][col].service,n),'\t\t\t\t\t',m[lin][col].client)

def clear_finish(m):
    for lin in range(30):
        date = []
        for col in range(3): # p = Serviços Prestados
            p = employ() # inicializo/preparo a a variável para representar a estrutura
            p.number = 0
            p.value = 0.0
            p.service = 0
            p.client = 0
            date.append(p)
        m.append(date)

def main():
    op = options() # esta função/método nos dá o retorno da opção que o usuário digitou/escolheu
    kind_employ = []
    employ_finish = []
    clear_finish (employ_finish)
    while op >= 1 and op <= 7: # o número 8 não está aqui, pois é para encerrar a repetição
        if op == 1:
            v_ts = register(kind_employ)
        elif op == 2:
            show_kind(v_ts) # pega o vetor já preenchido pelo usuário no cadastro do tipo de serviço
        elif op == 3:
            register_employ(employ_finish,kind_employ)
        elif op == 4:
            show_employ(employ_finish)
        elif op == 5:
            a = int(input("informe o dia da pesquisa: ")) - 1
            b = a+1
            show_day(a,b,employ_finish)
        elif op == 6:
            a = (int(input("qual o menor valor para a pesquisa ...")) -1)
            b = (int(input("qual o maior valor para a pesquisa ...")) -1)
            show_value(a,b,employ_finish)
        elif op == 7:
            show_month(employ_finish,kind_employ)
        op = options()

    print('\nTermino do programa...............')

main()
# Out:
# *** opções disponivel ***
# 1. Cadastrar os tipos de serviços
# 2. Mostrar todos os tipos de serviço
# 3. Cadastrar os serviços prestados
# 4. Mostrar todos os serviços prestados
# 5. Mostrar os serviços prestados em determinado dia
# 6. Mostrar os serviços prestados dentro de um intervalo de valor
# 7. Mostrar um relatório geral (separado por dia), que exiba, inclusive, a descrição do tipo do serviço
# 8. Sair
# *************************
# informe a opção desejada..1
# Cadastre o número do tipo de serviço: 1
# Cadastre a descrição do tipo de serviço: jardinagem
# Cadastre o número do tipo de serviço: 2
# Cadastre a descrição do tipo de serviço: pintura
# Cadastre o número do tipo de serviço: 3
# Cadastre a descrição do tipo de serviço: reforma
# Cadastre o número do tipo de serviço: 4
# Cadastre a descrição do tipo de serviço: faxina
# *** opções disponivel ***
# 1. Cadastrar os tipos de serviços
# 2. Mostrar todos os tipos de serviço
# 3. Cadastrar os serviços prestados
# ...
