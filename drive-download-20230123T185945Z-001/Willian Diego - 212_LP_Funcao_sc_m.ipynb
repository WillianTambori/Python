# %% [markdown]
# ### 1. (Função sem retorno com parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2, apresente o resultado.

# %%
def multiplicar(num): # a vrável num é nomeada como parâmetro
# NA DEFINIÇÃO DA FUNÇÃO E (num = numero) o valor de numero é COPIADO na num
    r = num * 2
    print(" o resultado da multiplicação é ",r)
def main():
    numero = int(input("digite um número: "))
    multiplicar(numero)# a variável numero nomeada como argumento NA CHAMADA DA FUNÇÃO


main()
# Out:
# digite um número: 7
#  o resultado da multiplicação é  14

# %%
#definição/declaração da função -
#determinação da lógica
# SEM RETORNO E COM PARÂMETRO
#Apresentar a frase 'Olá, tudo Fulano' a um nome
def mostrar_mensagem1():# SEM parâmetro
    nome1= input("Informe o nome 1: ")
    print('Olá, tudo bem',nome1,'?')

def mostrar_mensagem2(x):# COM parâmetro
    print('Olá, tudo bem',x,'?')
def main():
    mostrar_mensagem1()
    nome2 = input("Informe o nome 2: ")
    mostrar_mensagem2(nome2)# a variável nome é
    # repassada/copiada para a outra variável
    # que esta na definição da função
main()
# Out:
# Informe o nome 1: willian
# Olá, tudo bem willian ?
# Informe o nome 2: ana
# Olá, tudo bem ana ?

# %% [markdown]
# ### 2. (Função sem retorno com parâmetro) Faça um programa contendo uma função/método para subtrair dois números e apresentar o resultado.

# %%
def subtrair(x,y):
    subtrair = x - y
    print("a subtração dos numeros é :",subtrair)
def main():
    A = int(input("informe o numero : "))
    B = int(input("informe o outro numero: "))
    subtrair(A,B)
main()
# Out:
# informe o numero : 3
# informe o outro numero: 2
# a subtração dos numeros é : 1

# %% [markdown]
# ### 3. (Função sem retorno com parâmetro) Faça uma função/método para a partir de um preço de um produto informado, calcular e apresentar o novo preço reajustado em 9%.

# %%
def reajuste(a):
    x = a * 1.09
    print("o preço do produto foi para :",x)
def main():
    p =  float(input("informe o preço do produto :"))
    reajuste(p)
main()
# Out:
# informe o preço do produto :1000
# o preço do produto foi para : 1090.0

# %% [markdown]
# ### 4. (Função sem retorno com parâmetro) Faça uma função/método para a partir de um preço de um produto informado, calcular e apresentar o novo preço reajustado em alguma porcentagem que deve ser informada (digitada) pelo usuário.

# %%
def produto(x,y):
    reajuste = x * (1 + y/100)
    print("o preço reajustado é : %.2F"% reajuste)
def main():
    preço = float(input("informe o preço do produto: "))
    porcentagem = int(input("informe a porcentagem de reajuste: "))
    produto(preço,porcentagem)
main()
# Out:
# informe o preço do produto: 1000
# informe a porcentagem de reajuste: 20
# o preço reajustado é : 1200.00

# %% [markdown]
# ### 5. (Função sem retorno com parâmetro) Faça uma função/método para a partir de um valor inicial e um valor final realizar o acumulo desse valores e apresentar o resultado. Não use vetor.
#     Exemplo:
#         a = 2
#         b = 8
#         // 2 + 3 + 4 + 5 + 6 + 7 + 8 = 35
#         r = 35

# %%
def acumulo(x,y):
    soma = 0
    for i in range(x,y+1):
        soma += i
    print("o resultado da soma é :",soma)
def main():
    a = int(input("informe o numero inícial da conta: "))
    b = int(input("informe o numero final daconta: "))
    acumulo(a,b)
main()
# Out:
# informe o numero inícial da conta: 2
# informe o numero final daconta: 8
# o resultado da soma é : 35

# %% [markdown]
# ### 6. (Função sem retorno com parâmetro) Faça uma função/método para calcular a tabuada de um número informado pelo usuário.

# %%
def tabuada(x):
    for i in range(1,11):
        print(" %i x %i = %i " % (x,i,(x*i)))
    print()
def main():
    n = int(input("insira o numero da tabuada: "))
    tabuada(n)
main()
# Out:
# insira o numero da tabuada: 3
#  3 x 1 = 3
#  3 x 2 = 6
#  3 x 3 = 9
#  3 x 4 = 12
#  3 x 5 = 15
#  3 x 6 = 18
#  3 x 7 = 21
#  3 x 8 = 24
#  3 x 9 = 27
#  3 x 10 = 30

# %% [markdown]
# ### 7. (Função sem retorno com parâmetro) Faça uma função/método que calcule a média de um aluno que realizou duas provas (P1 e P2), a partir desta média, chame/crie OUTRA função que verifique se esta média aprova ou reprova o aluno.

# %%
def calcular_media(nota1, nota2):
    media = (nota1 + nota2) / 2
    print('Sua média é', media)
    verificar_aprovacao(media)
def verificar_aprovacao(m):
    if m >= 6:
        print('Aluno aprovado')
    else:
        print('Aluno reprovado')
def main():
    p1 = float(input('Digite a primeira nota: '))
    p2 = float(input('Digite a segunda nota: '))
    calcular_media(p1, p2)
main()
# Out:
# Digite a primeira nota: 9
# Digite a segunda nota: 8
# Sua média é 8.5
# Aluno aprovado

# %% [markdown]
# ### 8. (Função sem retorno com parâmetro) Faça uma função/método sem parâmetro, para ler um valor e chamar/criar OUTRA função (com parâmetro) que mostre se o valor é par ou ímpar.

# %%
def ParImpar(x):
    resto = x % 2
    resultado(resto)
def resultado(x):
    print("O numero informado é par" if x == 0 else "O numero informado é impar")
def main():
    n = int(input("informe o numero a ser avalidado :"))
    ParImpar(n)
main()
# Out:
# informe o numero a ser avalidado :7
# O numero informado é impar

# %% [markdown]
# ### 9. (Função sem retorno com parâmetro) Faça uma função/método para verificar se um nome digitado é igual a ‘Ana’, mostre o valor True ou False como resposta.

# %%
def igual(x):
    print("True" if x == "Ana" else "False" )
def main():
    nome = input("digite o nome Ana :")
    igual(nome)
main()
# Out:
# digite o nome Ana :Ana
# True

# %% [markdown]
# ### 10. (Função sem retorno com parâmetro) Faça uma função/método para verificar e contar quantas letras **a** tem numa frase. Não use NENHUMA função pronta da linguagem Python.

# %%
def frase(x):
    soma = 0 
    q= len(x)
    for i in range(q):
        if x[i] == "a":
            soma += 1
    print("A letra 'a' apareceu ",soma," vezes na frase :",x)
    
def main():
    escreva = input("escreva a frase : ")
    frase(escreva)
main()
# Out:
# escreva a frase : a menina ana
# A letra 'a' apareceu  4  vezes na frase : a menina ana
